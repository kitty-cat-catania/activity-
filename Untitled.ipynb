# %%
import os 
import pandas as pd
from config import key_dict

# %%
census_key = key_dict['census']

# %%
data_path= "Resources/deaths.csv"

# %%
data_df = pd.read_csv(data_path)

# %%
data_df.head()
# Out:
#    Data as of  Start Date    End Date          State     Age group  \
# 0  03/17/2021  01/01/2020  03/13/2021  United States      All Ages
# 1  03/17/2021  01/01/2020  03/13/2021  United States      All Ages
# 2  03/17/2021  01/01/2020  03/13/2021  United States  Under 1 year
# 3  03/17/2021  01/01/2020  03/13/2021  United States    0-17 years
# 4  03/17/2021  01/01/2020  03/13/2021  United States     1-4 years
#
#   Race and Hispanic Origin Group COVID-19 Deaths Total Deaths  \
# 0                   Total Deaths         517,651    3,967,901
# 1             Non-Hispanic White         316,019    2,909,394
# 2             Non-Hispanic White              12        8,676
# 3             Non-Hispanic White              63       16,030
# 4             Non-Hispanic White              10        1,713
#
#   Pneumonia Deaths Pneumonia and COVID-19 Deaths Influenza Deaths  \
# 0          445,769                       251,252            8,982
# ...
