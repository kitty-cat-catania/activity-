# %%
pip install sodapy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from sodapy import Socrata

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.cdc.gov", None)

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.cdc.gov,
#                  MyAppToken,
#                  userame="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("n8mc-b4w4",limit=2000000)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
results_df
# Out:
#         case_month res_state state_fips_code  res_county county_fips_code  \
# 0          2020-01        NA              NA          NA               NA
# 1          2020-01        NA              NA          NA               NA
# 2          2020-01        NA              NA          NA               NA
# 3          2020-01        NA              NA          NA               NA
# 4          2020-01        NA              NA          NA               NA
# ...            ...       ...             ...         ...              ...
# 1999995    2021-01        PA              42  WASHINGTON            42125
# 1999996    2021-01        PA              42  WASHINGTON            42125
# 1999997    2021-01        PA              42  WASHINGTON            42125
# 1999998    2021-01        PA              42  WASHINGTON            42125
# 1999999    2021-01        PA              42  WASHINGTON            42125
#
#               age_group     sex     race ethnicity  process exposure_yn  \
# ...

# %%
age_df=results_df[['case_month','res_state','res_county','age_group','sex','ethnicity']]
age_df
# Out:
#         case_month res_state  res_county       age_group     sex ethnicity
# 0          2020-01        NA          NA              NA      NA        NA
# 1          2020-01        NA          NA              NA      NA        NA
# 2          2020-01        NA          NA              NA      NA        NA
# 3          2020-01        NA          NA              NA      NA        NA
# 4          2020-01        NA          NA              NA      NA        NA
# ...            ...       ...         ...             ...     ...       ...
# 1999995    2021-01        PA  WASHINGTON  18 to 49 years  Female   Unknown
# 1999996    2021-01        PA  WASHINGTON  18 to 49 years  Female   Unknown
# 1999997    2021-01        PA  WASHINGTON  18 to 49 years  Female   Unknown
# 1999998    2021-01        PA  WASHINGTON  18 to 49 years  Female   Unknown
# 1999999    2021-01        PA  WASHINGTON  18 to 49 years  Female   Unknown
#
# [2000000 rows x 6 columns]

# %%
age_df.dropna()
# Out:
#         case_month res_state  res_county       age_group     sex ethnicity
# 0          2020-01        NA          NA              NA      NA        NA
# 1          2020-01        NA          NA              NA      NA        NA
# 2          2020-01        NA          NA              NA      NA        NA
# 3          2020-01        NA          NA              NA      NA        NA
# 4          2020-01        NA          NA              NA      NA        NA
# ...            ...       ...         ...             ...     ...       ...
# 1999995    2021-01        PA  WASHINGTON  18 to 49 years  Female   Unknown
# 1999996    2021-01        PA  WASHINGTON  18 to 49 years  Female   Unknown
# 1999997    2021-01        PA  WASHINGTON  18 to 49 years  Female   Unknown
# 1999998    2021-01        PA  WASHINGTON  18 to 49 years  Female   Unknown
# 1999999    2021-01        PA  WASHINGTON  18 to 49 years  Female   Unknown
#
# [2000000 rows x 6 columns]

# %%
selceted_df=age_df.loc[age_df['case_month']<='2020-12']

# %%
selceted_df['res_state'].astype('string')
# Out:
# 0          NA
# 1          NA
# 2          NA
# 3          NA
# 4          NA
#            ..
# 1999930    PA
# 1999931    PA
# 1999932    PA
# 1999933    PA
# 1999934    PA
# Name: res_state, Length: 1497688, dtype: string

# %%
selceted_df
# Out:
#         case_month res_state  res_county       age_group     sex ethnicity
# 0          2020-01        NA          NA              NA      NA        NA
# 1          2020-01        NA          NA              NA      NA        NA
# 2          2020-01        NA          NA              NA      NA        NA
# 3          2020-01        NA          NA              NA      NA        NA
# 4          2020-01        NA          NA              NA      NA        NA
# ...            ...       ...         ...             ...     ...       ...
# 1999930    2020-07        PA  WASHINGTON  18 to 49 years  Female   Unknown
# 1999931    2020-07        PA  WASHINGTON  18 to 49 years  Female   Unknown
# 1999932    2020-07        PA  WASHINGTON  18 to 49 years  Female   Unknown
# 1999933    2020-07        PA  WASHINGTON  18 to 49 years  Female   Unknown
# 1999934    2020-07        PA  WASHINGTON  18 to 49 years  Female   Unknown
#
# [1497688 rows x 6 columns]

# %%
test_selceted_df=selceted_df

# %%
test_selceted_df['res_state'].astype('string')
test_selceted_df['res_state'].drop('NA', axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
#     367         try:
# --> 368             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     369         except KeyError:
#
# KeyError: 1
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-76-4a5a37f390dc> in <module>
#       1 test_selceted_df['res_state'].astype('string')
# ----> 2 test_selceted_df['res_state'].drop('NA', axis=1)
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4495         dtype: float64
#    4496         """
# -> 4497         return super().drop(
#    4498             labels=labels,
#    4499             axis=axis,
#
# ...

# %%
selceted_df.res_state.nunique()
# Out:
# 55
